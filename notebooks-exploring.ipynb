# %% [markdown]
# Hola Esto es de solo salida

# %%
print('Hello')
# Out:
# Hello

# %%
# !pip list | grep seaborn
# Out:
# seaborn                         0.12.2
#
# [notice] A new release of pip available: 22.2.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from random import random
# %time rand=[random() for i in range(0,100)]
# Out:
# CPU times: user 24 µs, sys: 0 ns, total: 24 µs
# Wall time: 27.7 µs

# %% [markdown]
# Comando ejecutado

# %%
# %ls /
# Out:
# afs/   dev/    home/   lost+found/  opt/   run/   sys/  var/
# bin@   etc/    lib@    media/       proc/  sbin@  tmp/
# boot/  help.1  lib64@  mnt/         root/  srv/   usr/

# %%
import os

pid = os.getpid()

# %%
os.getgid()
# Out:
# 0

# %%
pid
# Out:
# 277

# %%
# %pwd
# %ls
# Out:
# notebooks-exploring.ipynb  risas.jpg

# %%
from IPython import display
display.Image("risas.jpg", width=100, height=100)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, 5, 100)
y = np.sin(x)

plt.plot(x, y, linewidth=2.0)
plt.show()
